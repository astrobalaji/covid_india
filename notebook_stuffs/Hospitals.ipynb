# %%
import pandas as pd

# %% [markdown]
# Tamil Nadu

# %%
df = pd.read_html("https://stopcorona.tn.gov.in/beds.php")[0]

# %%
df
# Out:
#     S.NO      District                               Institution  \
#     S.NO      District                               Institution
# 0      1      Ariyalur                              A.S Hospital
# 1      2      Ariyalur                           Golden Hospital
# 2      3  Chengalpattu                       Annai Arul Hospital
# 3      4  Chengalpattu      Chennai Emergency care Centre Pammal
# 4      5  Chengalpattu                        Dr. Rela Institute
# ..   ...           ...                                       ...
# 445  446      Tiruppur                  Vel Hospital, Dharapuram
# 446  447      Tiruppur                    Vel Hospital,Udumalpet
# 447  448       Madurai                           Vijaya Hospital
# 448  449       Madurai  Vikram Multispeciality hospital, Madurai
# 449  450       Chennai       Westminster HealthCare,Nungambakkam
#
#     BEDS ALLOCATED FOR COVID AND SUSPECTED CASES                  \
# ...

# %%
df['BEDS ALLOCATED FOR COVID AND SUSPECTED CASES']
# Out:
#      Total  Occupied  Vacant
# 0       25        13      12
# 1       31        10      21
# 2       40        40       0
# 3       10        10       0
# 4        0       300    -300
# ..     ...       ...     ...
# 445      0         0       0
# 446      0         0       0
# 447      0         0       0
# 448      0         0       0
# 449      0         0       0
#
# [450 rows x 3 columns]

# %%
df = pd.read_html("../data/CH_data.html", skiprows=4)[0]

# %%
df.columns = df.loc[0]
df.drop([0], axis = 0)
# Out:
# 0   S.No District Name                  Hospital Name  \
# 1      1       SURGUJA             Sai Hostel Sarguja
# 2      2       SURGUJA  Jeevan Jyoti Hospital SURGUJA
# 3      3       SURGUJA                    CHC MAINPAT
# 4      4       SURGUJA                    CHC BATOULI
# 5      5       SURGUJA                   CHC DHOURPUR
# ..   ...           ...                            ...
# 348  348         BALOD       ITI Khallari, Gunderdehi
# 349  349         BALOD             ITI Dhanora, Gurur
# 350  350         BALOD       Livelyhood College Balod
# 351  351         BALOD        District Hospital Balod
# 352  NaN           NaN                            NaN
#
# 0           Hospital Category Total Number Of covid Beds  \
# 1           Covid Care Center                         50
# 2            Private Hospital                         62
# 3           Covid Care Center                         35
# 4           Covid Care Center                          4
# ...

# %%
pd.read_csv('../data/hospitals_cleaned.csv')
# Out:
#           state                                            pointer
# 0      Taminadu              https://stopcorona.tn.gov.in/beds.php
# 1  Chattisgarh   https://cg.nic.in/health/covid19/RTPBedAvailab...
# 2   West Bengal  https://www.wbhealth.gov.in/uploaded_files/cor...
# 3       Odisha   https://health.odisha.gov.in/pdf/List-COVID-fa...
# 4    Karnataka   https://covid19.karnataka.gov.in/new-page/Desi...
