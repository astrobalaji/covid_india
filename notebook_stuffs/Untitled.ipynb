# %%
import pandas as pd

# %%
google_url = "https://docs.google.com/spreadsheets/d/1wu80sP5tq2k9bfxjuzUfRORxPDf07gUALfLMrOv-YEI/export?format=csv&gid"

# %%
df = pd.read_csv("https://docs.google.com/spreadsheets/d/1wu80sP5tq2k9bfxjuzUfRORxPDf07gUALfLMrOv-YEI/export?format=csv&gid")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-2-ed2cad245c15> in <module>
# ----> 1 df = pd.read_csv("https://docs.google.com/spreadsheets/d/1wu80sP5tq2k9bfxjuzUfRORxPDf07gUALfLMrOv-YEI/export?format=csv&gid")
#
# ...

# %%
df = pd.read_html("https://docs.google.com/spreadsheets/u/0/d/1J-m84rr-tV47wZrUKn41jlTTID5FNcMs5MwyYHt9fLU/htmlview")

# %%
len(df)
# Out:
# 1

# %%
df = df[0]

# %%
df
# Out:
#      Unnamed: 0   A                            B  \
# 0             1 NaN                          NaN
# 1             2 NaN  Remdesivir Distributor List
# 2             3 NaN                        State
# 3             4 NaN                Andra Pradesh
# 4             5 NaN                Andra Pradesh
# ..          ...  ..                          ...
# 497         498 NaN                  Uttaranchal
# 498         499 NaN                  Uttaranchal
# 499         500 NaN                  West Bengal
# 500         501 NaN                  West Bengal
# 501         502 NaN                  West Bengal
#
#                                        C  \
# 0                                    NaN
# 1            Remdesivir Distributor List
# 2                       Distributor Name
# 3                        AUROBINDO DRUGS
# 4             BALAJI MEDICAL CORPORATION
# ..                                   ...
# 497               RUCHI MEDICAL PVT. LTD
# ...

# %%
glink = "https://docs.google.com/spreadsheets/d/1-HDRXAnMGkFIr8HQB_fUaZiL70c-rSuShYYfO2U6754/export?format=csv&gid=0"

# %%
df = pd.read_csv(glink)

# %%
df['Facility offered'].unique()
# Out:
# array(['Plasma Donation', 'Plasma Donors', 'Bed',
#        'Remdisvir And Tocilizumab', 'Ambulances with ventilators',
#        'Oxygen Cylinders', 'Meals', 'Tocilizumab', nan, 'HELPLINE NUMBER'],
#       dtype=object)

# %%
test = pd.read_html("https://stopcorona.tn.gov.in/beds.php")

# %%
test[0]
# Out:
#     S.NO      District                                        Institution  \
#     S.NO      District                                        Institution
# 0      1      Ariyalur                                       A.S Hospital
# 1      2      Ariyalur                                    Golden Hospital
# 2      3  Chengalpattu                                Annai Arul Hospital
# 3      4  Chengalpattu               Chennai Emergency care Centre Pammal
# 4      5  Chengalpattu                                 Dr. Rela Institute
# ..   ...           ...                                                ...
# 391  392    Coimbatore                   Gem Hospital and Research centre
# 392  393    Coimbatore                               N.M. Hospital, Annur
# 393  394      Namakkal  Swamy Vivekanandha Medical College Hospital an...
# 394  395    Tiruvallur                               Be well , Ponamallee
# 395  396     Thanjavur                                    National pharma
#
# ...

# %%
import pandas as pd

# %%
test = pd.read_html("https://cg.nic.in/health/covid19/RTPBedAvailable.aspx")

# %%
test
# Out:
# [                                                   0
#  0             Hospital Wise Bed Availability Details
#  1  Select Hospital Category : ALL Category \tCovi...
#  2   Current Date : 21-04-2021 Current Time :17:57:50]
