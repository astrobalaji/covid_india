# %%
import pandas as pd

# %%
df = pd.read_csv("https://docs.google.com/spreadsheets/d/1J-m84rr-tV47wZrUKn41jlTTID5FNcMs5MwyYHt9fLU/export?format=csv&gid=0", skiprows= 2)

# %%
df.drop(df.filter(like = 'Unnamed').columns, axis = 1, inplace = True)

# %%
df
# Out:
#              State                     Distributor Name  \
# 0    Andra Pradesh                      AUROBINDO DRUGS
# 1    Andra Pradesh           BALAJI MEDICAL CORPORATION
# 2    Andra Pradesh                AUROBINDO DRUGS (GNT)
# 3    Andra Pradesh             KRANTHI MEDICAL AGENCIES
# 4    Andra Pradesh           PARAMOUNT MEDICAL AGENCIES
# ..             ...                                  ...
# 494    Uttaranchal               RUCHI MEDICAL PVT. LTD
# 495    Uttaranchal          VISHAL MEDICO AGENCIES (CE)
# 496    West Bengal       Adeline Pharma Private Limited
# 497    West Bengal     Adeline Pharma pvt. Ltd (Apollo)
# 498    West Bengal  FRIENDS SPECIALITY MEDICINE pvt. lt
#
#                                                Address  \
# 0    D.NO:8-72, BLOCK-IIPRASAD PLAZA,KAMAIAHTHOPU C...
# 1    9-10-51A, D.S BUILDINGSNAAZ CENTREGUNTUR 522 0...
# 2    D.NO:8-72, BLOCK-IIPRASAD PLAZA,KAMAIAHTHOPU C...
# 3    OLD GOVT HOSPITAL ROAD,BEHIND AMBETHKAR\nSTATU...
# 4    30-8-7, BHANU\nSTREETDABAGARDENSVISAKHAPATNAM,...
# ..                                                 ...
# 494  18 P.D TANDON MARGLAXMAN CHOWKDEHRADUN,DEHRADU...
# 495  KHANCHAND MARKET,HALDWANI  263 139,HALDWANI,26...
# 496          105, Mahatma Gandhi Road..,Kolkata,700104
# 497  B1, Rishi Tech Park, Premises no. 02-3602nd fl...
# 498  2ND FLOORPLOT XI 16BLOCK EP & GPSECTOR V  , SA...
#
#                          E-Mail Address              Telephone
# 0              aurobindodrugs@gmail.com           0866-3202242
# 1                  bmcguntur1@gmail.com             9849828896
# 2              aurobindodrugs@gmail.com           0866-3202242
# 3                      pcsr79@yahoo.com             9246472006
# 4    paramountmedicalagencies@gmail.com             9849112421
# ..                                  ...                    ...
# 494             neeraj@ruchimedical.com             9634094090
# 495           vishalmedicohld@gmail.com             9997907770
# 496         adelinepharma2016@gmail.com  9831041904 9748472456
# 497         adelinepharma2016@gmail.com           033-66120102
# 498                 kolkata@fsmpl.co.in             8443902900
#
# [499 rows x 5 columns]

# %%
def jaccard_similarity(list1, list2):
    intersection = len(list(set(list1).intersection(list2)))
    union = (len(list1) + len(list2)) - intersection
    return float(intersection) / union
